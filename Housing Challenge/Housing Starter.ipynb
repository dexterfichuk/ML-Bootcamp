# %% [markdown]
# # TD Lab ML Championship!
# ## Loading the Data
# Firstly, I've loaded in the traingingdata for you to a variable called df. I've then split the input data to variable X, and the target predictions to variable y!
#
# To score your model, you'll want to minimize the root mean squared error with the function I created. (A lower number is better) It can be used as follows:
# ```
# rmse(predicitons, y_true)
# ```

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

def rmse(y_pred, y_true):
    return np.sqrt(mean_squared_error(y_pred,y_true))

df = pd.read_csv("housing_data.csv")

y = df.house_price
X = df.drop(["house_price"], axis=1)

df.head() #Hint, remember that the date is in string format
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5467910190  20140527T000000         3       1.75         1780     13095
# 1  9331800580  20150310T000000         2       1.00         1000      3700
# 2  2407000405  20150226T000000         3       1.00         1080      7486
# 3  5466700290  20150108T000000         3       2.25         2090      7500
# 4  3026059361  20150417T000000         2       2.50         1741      1439
#
#    floors  waterfront  view  condition     ...       sqft_above  \
# 0     1.0           0     0          4     ...             1780
# 1     1.0           0     0          3     ...              800
# 2     1.5           0     0          3     ...              990
# 3     1.0           0     0          4     ...             1280
# 4     2.0           0     0          3     ...             1446
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Add in your own model code in this area and feel free to add cells

# %% [markdown]
# # Submission Time
# I've loaded in the data to a variable called test set, you must then perform any pre-processing you did on your training data to this set, then perform a prediction with your top model. Afterwards, you can go submit your score here to see your place on the leaderboard!

# %%
test = pd.read_csv("housing_test_set.csv")

test.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2591820310  20141006T000000         4       2.25         2070      8893
# 1  7974200820  20140821T000000         5       3.00         2900      6730
# 2  7701450110  20140815T000000         4       2.50         3770     10893
# 3  9522300010  20150331T000000         3       3.50         4560     14608
# 4  9510861140  20140714T000000         3       2.50         2550      5376
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     2.0           0     0          4      8        2070              0
# 1     1.0           0     0          5      8        1830           1070
# 2     2.0           0     2          3     11        3770              0
# 3     2.0           0     2          3     12        4560              0
# 4     2.0           0     0          3      9        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# Do your code and preprocessing inbetwee, this, and the prediction saver

# %%
submission = pd.DataFrame()
submission["pred"] = list() #set preds to your predictions (put them in the lists brackets)

pred_size = len(submission.pred)

if pred_size == 4323:
    # Afterwards, submit this prediciton file to the site
    submission.to_csv("predictions.csv", index=None)
else:
    print("Sorry, you need to have 4323 predictions!")
